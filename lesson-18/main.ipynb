# %% [markdown]
# ## Pandas 1

# %%
import pandas as pd
import numpy as np

# %%
# series
import pandas as pd
import numpy as np


ls = [1,2,3,4,7,8]
ls2 = [3,4,5,6]
print('python native list: ', ls)
arr = np.array(ls)
arr2 = np.array(ls2)
print('numpy array: ', arr)
ser = pd.Series(arr)
ser2 = pd.Series(arr2)
print('pandas series:', ser)
# Out:
# python native list:  [1, 2, 3, 4, 7, 8]
# numpy array:  [1 2 3 4 7 8]
# pandas series: 0    1
# 1    2
# 2    3
# 3    4
# 4    7
# 5    8
# dtype: int64

# %%
print(ser[0])
print(ser[1])
print(ser[0:2])
print(ser[0::2])
# Out:
# 1
# 2
# 0    1
# 1    2
# dtype: int64
# 0    1
# 2    3
# dtype: int64

# %%
print(ser.mean())
print(ser.min())
print(ser.max())
# Out:
# 2.5
# 1
# 4

# %%
print(ser + ser2)
print(ser - ser2)
print(ser * ser2)
print(ser / ser2)
# Out:
# 0     4.0
# 1     6.0
# 2     8.0
# 3    10.0
# 4     NaN
# 5     NaN
# dtype: float64
# 0   -2.0
# 1   -2.0
# 2   -2.0
# 3   -2.0
# 4    NaN
# 5    NaN
# dtype: float64
# 0     3.0
# 1     8.0
# 2    15.0
# 3    24.0
# 4     NaN
# 5     NaN
# dtype: float64
# 0    0.333333
# 1    0.500000
# 2    0.600000
# 3    0.666667
# 4         NaN
# 5         NaN
# dtype: float64

# %%
filt = ser % 2 == 0
filt1 = (ser > 3) & (ser < 7)
print(ser[filt])
print(ser[filt1])
# Out:
# 1    2
# 3    4
# 5    8
# dtype: int64
# 3    4
# dtype: int64

# %%
ser.describe()
# Out:
# count    6.000000
# mean     4.166667
# std      2.786874
# min      1.000000
# 25%      2.250000
# 50%      3.500000
# 75%      6.250000
# max      8.000000
# dtype: float64

# %%
data = {
        "id": [1,2,3,4,5,6,7],
        "name": ['mukhlisa', 'samandar', 'nodir', 'nabohat', 'inobat', 'muhammadbotir', 'najmiddin'],
        "python_mid_score": [90, 80, 95, 85, 95, 85, 80]
        }

data
# Out:
# {'id': [1, 2, 3, 4, 5, 6, 7],
#  'name': ['mukhlisa',
#   'samandar',
#   'nodir',
#   'nabohat',
#   'inobat',
#   'muhammadbotir',
#   'najmiddin'],
#  'python_mid_score': [90, 80, 95, 85, 95, 85, 80]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    id           name  python_mid_score
# 0   1       mukhlisa                90
# 1   2       samandar                80
# 2   3          nodir                95
# 3   4        nabohat                85
# 4   5         inobat                95
# 5   6  muhammadbotir                85
# 6   7      najmiddin                80

# %%
ser[1]
# Out:
# np.int64(2)

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Inobat\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df[0]
#
# ...

# %%
df.head(3)
# Out:
#    id      name  python_mid_score
# 0   1  mukhlisa                90
# 1   2  samandar                80
# 2   3     nodir                95

# %%
df.tail(2)
# Out:
#    id           name  python_mid_score
# 5   6  muhammadbotir                85
# 6   7      najmiddin                80

# %%
df.columns
# Out:
# Index(['id', 'name', 'python_mid_score'], dtype='object')

# %%
df["name"]
# Out:
# 0         mukhlisa
# 1         samandar
# 2            nodir
# 3          nabohat
# 4           inobat
# 5    muhammadbotir
# 6        najmiddin
# Name: name, dtype: object

# %%
df[["id", "name"]]
# Out:
#    id           name
# 0   1       mukhlisa
# 1   2       samandar
# 2   3          nodir
# 3   4        nabohat
# 4   5         inobat
# 5   6  muhammadbotir
# 6   7      najmiddin

# %%
print(type(df["name"]))
print(type(df[["id", "name"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
df * 2
# Out:
#    id                        name  python_mid_score
# 0   2            mukhlisamukhlisa               180
# 1   4            samandarsamandar               160
# 2   6                  nodirnodir               190
# 3   8              nabohatnabohat               170
# 4  10                inobatinobat               190
# 5  12  muhammadbotirmuhammadbotir               170
# 6  14          najmiddinnajmiddin               160

# %%
filt = df['python_mid_score'] > 80
df[filt]
# Out:
#    id           name  python_mid_score
# 0   1       mukhlisa                90
# 2   3          nodir                95
# 3   4        nabohat                85
# 4   5         inobat                95
# 5   6  muhammadbotir                85

# %%
df['sql_mid_score'] = 80
df
# Out:
#    id           name  python_mid_score  sql_mid_score
# 0   1       mukhlisa                90             80
# 1   2       samandar                80             80
# 2   3          nodir                95             80
# 3   4        nabohat                85             80
# 4   5         inobat                95             80
# 5   6  muhammadbotir                85             80
# 6   7      najmiddin                80             80

# %%
df['name'][0] = 'Mukhlisa' #not recommended
df
# Out:
# C:\Users\Inobat\AppData\Local\Temp\ipykernel_9076\941829969.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['name'][0] = 'Mukhlisa'
# ...

# %%
# better to change with at

df.at[5,'name'] = 'Muhammadbotir'
df
# Out:
#    id           name  python_mid_score  sql_mid_score
# 0   1       Mukhlisa                90             80
# 1   2       samandar                80             80
# 2   3          nodir                95             80
# 3   4        nabohat                85             80
# 4   5         inobat                95             80
# 5   6  Muhammadbotir                85             80
# 6   7      najmiddin                80             80

# %%
# rename returns new dataframe
# to affect existing one either inplace=True or equal to variable itself

df.rename(columns={'name': 'Name'})
# Out:
#    id           Name  python_mid_score  sql_mid_score
# 0   1       Mukhlisa                90             80
# 1   2       samandar                80             80
# 2   3          nodir                95             80
# 3   4        nabohat                85             80
# 4   5         inobat                95             80
# 5   6  Muhammadbotir                85             80
# 6   7      najmiddin                80             80

# %%
df.rename(columns={'name': 'Name'},inplace=True)
df
# Out:
#    id           Name  python_mid_score  sql_mid_score
# 0   1       Mukhlisa                90             80
# 1   2       samandar                80             80
# 2   3          nodir                95             80
# 3   4        nabohat                85             80
# 4   5         inobat                95             80
# 5   6  Muhammadbotir                85             80
# 6   7      najmiddin                80             80

# %%
df =df.rename(columns={'name': 'Name'})
df
# Out:
#    id           Name  python_mid_score  sql_mid_score
# 0   1       Mukhlisa                90             80
# 1   2       samandar                80             80
# 2   3          nodir                95             80
# 3   4        nabohat                85             80
# 4   5         inobat                95             80
# 5   6  Muhammadbotir                85             80
# 6   7      najmiddin                80             80

# %%
df[0:2]
# Out:
#    id      Name  python_mid_score  sql_mid_score
# 0   1  Mukhlisa                90             80
# 1   2  samandar                80             80

# %%
df = pd.read_csv('mavie.csv')
df.head(1)
# Out:
#    Color     Director  Duration  IMDB_Rating  Votes  Revenue           Actor  \
# 0  Color  Alex Gibney      48.0          9.3  141.0     23.0  George W. Bush
#
#    Metascore     Gross                 Genres
# 0      141.0  274661.0  Crime|Documentary|War

# %%
# label --- appearance-- ['mukhlisa', 'samandar', 'nodir', 'nabohat', 'inobat', 'muhammadbotir', 'najmiddin'] - tashqi ko'rinish
# index --- position -- [0,1,2,3,4,5,6], 
# loc --- label
# iloc --- position

# %%
df.head(10)
# Out:
#    Color         Director  Duration  IMDB_Rating  Votes  Revenue  \
# 0  Color      Alex Gibney      48.0          9.3  141.0     23.0
# 1  Color     Paul Crowder       3.0         97.0   10.0      5.0
# 2  Color   Rohit Jagessar     120.0          8.0    0.0      0.0
# 3  Color    Griffin Dunne      13.0         90.0  165.0    679.0
# 4  Color   Anthony Powell      31.0         91.0    9.0      9.0
# 5  Color    Kief Davidson      43.0         93.0    0.0      0.0
# 6  Color      Johnny Remo       2.0        112.0   74.0    891.0
# 7  Color  Vivek Agnihotri       4.0        106.0    5.0    219.0
# 8  Color          Ti West     238.0         95.0  243.0    725.0
# 9  Color      Nick Tomnay     112.0         93.0   11.0    271.0
#
#              Actor  Metascore     Gross                           Genres
# 0   George W. Bush      141.0  274661.0            Crime|Documentary|War
# 1      Marv Albert      102.0  144431.0                Documentary|Sport
# ...

# %%
# first row, then column

df.loc[0:3, 'Director':'Votes']
# Out:
#          Director  Duration  IMDB_Rating  Votes
# 0     Alex Gibney      48.0          9.3  141.0
# 1    Paul Crowder       3.0         97.0   10.0
# 2  Rohit Jagessar     120.0          8.0    0.0
# 3   Griffin Dunne      13.0         90.0  165.0

# %%
df = df.set_index('Director')
df
# Out:
#                    Color  Duration  IMDB_Rating     Votes   Revenue  \
# Director
# Alex Gibney        Color      48.0          9.3     141.0      23.0
# Paul Crowder       Color       3.0         97.0      10.0       5.0
# Rohit Jagessar     Color     120.0          8.0       0.0       0.0
# Griffin Dunne      Color      13.0         90.0     165.0     679.0
# Anthony Powell     Color      31.0         91.0       9.0       9.0
# ...                  ...       ...          ...       ...       ...
# James Cameron      Color      96.0          7.9  128477.0  472627.0
# Christopher Nolan  Color     116.0          6.2   29502.0    5263.0
# Martin Scorsese    Color     130.0          7.6  404980.0  298881.0
# Steven Spielberg   Color     113.0          8.3  150422.0   22172.0
# Christopher Nolan  Color      99.0          7.0  465671.0  223320.0
#
#                                 Actor  Metascore     Gross  \
# Director
# Alex Gibney            George W. Bush      141.0  274661.0
# ...

# %%
df.loc['Paul Crowder':'Anthony Powell', 'Duration':'Votes']
# Out:
#                 Duration  IMDB_Rating  Votes
# Director
# Paul Crowder         3.0         97.0   10.0
# Rohit Jagessar     120.0          8.0    0.0
# Griffin Dunne       13.0         90.0  165.0
# Anthony Powell      31.0         91.0    9.0

# %%
df = df.reset_index()
df
# Out:
#      index           Director  Color  Duration  IMDB_Rating     Votes  \
# 0        0        Alex Gibney  Color      48.0          9.3     141.0
# 1        1       Paul Crowder  Color       3.0         97.0      10.0
# 2        2     Rohit Jagessar  Color     120.0          8.0       0.0
# 3        3      Griffin Dunne  Color      13.0         90.0     165.0
# 4        4     Anthony Powell  Color      31.0         91.0       9.0
# ..     ...                ...    ...       ...          ...       ...
# 155    155      James Cameron  Color      96.0          7.9  128477.0
# 156    156  Christopher Nolan  Color     116.0          6.2   29502.0
# 157    157    Martin Scorsese  Color     130.0          7.6  404980.0
# 158    158   Steven Spielberg  Color     113.0          8.3  150422.0
# 159    159  Christopher Nolan  Color      99.0          7.0  465671.0
#
#       Revenue               Actor  Metascore     Gross  \
# 0        23.0      George W. Bush      141.0  274661.0
# ...
