# %% [markdown]
# ## Pandas 2

# %%
import pandas as pd
import sqlalchemy as sa
import pyodbc 


df = pd.read_csv('student.csv')
csv_df = df[df['Extension'] == 'csv']
txt_df = df[df['Extension'] == 'txt']
sql_df = df[df['Extension'] == 'sql']



csv_df.to_csv('data/student.csv',index=False)
txt_df.to_csv('data/student.txt',index=False)

conn_str = "mssql+pyodbc://@DESKTOP-CSSCKLQ/Data?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
engine = sa.create_engine(conn_str)
connection = engine.connect()
sql_df.to_sql('student', connection, index=False, if_exists='replace')
print('Success')
# Out:
# Success

# %%
df.sort_values(['Extension', 'Age'],ascending=[True,False])
# Out:
#    ID  Name  Age Extension
# 6   7   Ann   26       csv
# 1   2  Sara   25       csv
# 4   5  Alex   23       csv
# 2   3   Ann   26       sql
# 5   6  Sara   25       sql
# 3   4   Bek   25       txt
# 7   8   Bek   25       txt
# 0   1  Alex   23       txt

# %%
d = {
    'Student': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'A'],
    'math' : [56, 67,75,34,85,83,49,80],
    'physics': [96, 57,65,74,65,53,69,78]
}

df = pd.DataFrame(d)
df
# Out:
#   Student  math  physics
# 0       A    56       96
# 1       B    67       57
# 2       C    75       65
# 3       D    34       74
# 4       E    85       65
# 5       F    83       53
# 6       G    49       69
# 7       A    80       78

# %%
# series

df['math']
# Out:
# 0    56
# 1    67
# 2    75
# 3    34
# 4    85
# 5    83
# 6    49
# 7    80
# Name: math, dtype: int64

# %%
# dataframe

df[['math', 'physics']]
# Out:
#    math  physics
# 0    56       96
# 1    67       57
# 2    75       65
# 3    34       74
# 4    85       65
# 5    83       53
# 6    49       69
# 7    80       78

# %%
df.set_index('Student')
# Out:
#          math  physics
# Student
# A          56       96
# B          67       57
# C          75       65
# D          34       74
# E          85       65
# F          83       53
# G          49       69
# A          80       78

# %%
df
# Out:
#   Student  math  physics
# 0       A    56       96
# 1       B    67       57
# 2       C    75       65
# 3       D    34       74
# 4       E    85       65
# 5       F    83       53
# 6       G    49       69
# 7       A    80       78

# %%
df.set_index('Student',inplace=True)
df
# Out:
#          math  physics
# Student
# A          56       96
# B          67       57
# C          75       65
# D          34       74
# E          85       65
# F          83       53
# G          49       69
# A          80       78

# %%
df
# Out:
#          math  physics
# Student
# A          56       96
# B          67       57
# C          75       65
# D          34       74
# E          85       65
# F          83       53
# G          49       69
# A          80       78

# %%
df.loc['B':'D', ['math','physics']]
df.loc['B':'D', ['math','physics']]
# Out:
#          math  physics
# Student
# B          67       57
# C          75       65
# D          34       74

# %%
df.loc['B':'D', 'math':'physics']
# Out:
#          math  physics
# Student
# B          67       57
# C          75       65
# D          34       74

# %%
# no index named as B. B, D are label

df.iloc['B':'D']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 # no index named as B. B, D are label
# ----> 3 df.iloc['B':'D']
#
# File c:\Users\Inobat\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Inobat\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1729, in _iLocIndexer._getitem_axis(self, key, axis)
#    1723     raise IndexError(
#    1724         "DataFrame indexer is not allowed for .iloc\n"
#    1725         "Consider using .loc for automatic alignment."
#    1726     )
#    1728 if isinstance(key, slice):
# ...

# %%
# even rows are in index

df.iloc[0:3, 0:1]
# Out:
#          math
# Student
# A          56
# B          67
# C          75

# %%
df.sort_values('math')
# Out:
#          math  physics
# Student
# D          34       74
# G          49       69
# A          56       96
# B          67       57
# C          75       65
# A          80       78
# F          83       53
# E          85       65

# %%
df.sort_values('math',ascending=False)
# Out:
#   Student  math  physics
# 4       E    85       65
# 5       F    83       53
# 7       A    80       78
# 2       C    75       65
# 1       B    67       57
# 0       A    56       96
# 6       G    49       69
# 3       D    34       74

# %%
df.sort_values(['Student', 'math'])
# Out:
#   Student  math  physics
# 0       A    56       96
# 7       A    80       78
# 1       B    67       57
# 2       C    75       65
# 3       D    34       74
# 4       E    85       65
# 5       F    83       53
# 6       G    49       69

# %%
df.sort_values(['Student', 'math'], ascending=[True, False])
# Out:
#   Student  math  physics
# 7       A    80       78
# 0       A    56       96
# 1       B    67       57
# 2       C    75       65
# 3       D    34       74
# 4       E    85       65
# 5       F    83       53
# 6       G    49       69

# %%
# nlargest - same as top 


df.nlargest(3, 'math')
# Out:
#   Student  math  physics
# 4       E    85       65
# 5       F    83       53
# 7       A    80       78

# %%
# mean, mode, median


ls = [1,2,2,3,4,3,5,6,3,5,3,5,5,5]

ser = pd.Series(ls)
print(ser.median())
print(ser.mode())
print(ser.mean())
# Out:
# 3.5
# 0    5
# dtype: int64
# 3.7142857142857144

# %%
df
# Out:
#   Student  math  physics
# 0       A    56       96
# 1       B    67       57
# 2       C    75       65
# 3       D    34       74
# 4       E    85       65
# 5       F    83       53
# 6       G    49       69
# 7       A    80       78

# %%
filt = df['math'] > df['math'].mean()

df[filt]
# Out:
#   Student  math  physics
# 1       B    67       57
# 2       C    75       65
# 4       E    85       65
# 5       F    83       53
# 7       A    80       78

# %%
filt = df['math'] > df['math'].mean()

# not - ~

df[~filt]
# Out:
#   Student  math  physics
# 0       A    56       96
# 3       D    34       74
# 6       G    49       69

# %%
df['Student'].value_counts()
# Out:
# Student
# A    2
# B    1
# C    1
# D    1
# E    1
# F    1
# G    1
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# Student  math  physics
# A        56    96         1
#          80    78         1
# B        67    57         1
# C        75    65         1
# D        34    74         1
# E        85    65         1
# F        83    53         1
# G        49    69         1
# Name: count, dtype: int64

# %%
df = pd.read_csv('employee.csv')


filter1 = df['DEPARTMENT'].isin(['Houston Police Department-HPD', 'Houston Fire Department (HFD)'])

df[filter1]
# Out:
#       UNIQUE_ID          POSITION_TITLE                     DEPARTMENT  \
# 2             2          POLICE OFFICER  Houston Police Department-HPD
# 3             3       ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 5             5   SENIOR POLICE OFFICER  Houston Police Department-HPD
# 10           10            FIRE FIGHTER  Houston Fire Department (HFD)
# 14           14         POLICE SERGEANT  Houston Police Department-HPD
# ...         ...                     ...                            ...
# 1995       1995          POLICE OFFICER  Houston Police Department-HPD
# 1996       1996  COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997          POLICE OFFICER  Houston Police Department-HPD
# 1998       1998          POLICE OFFICER  Houston Police Department-HPD
# 1999       1999            FIRE FIGHTER  Houston Fire Department (HFD)
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE GENDER  \
# ...

# %%
df = pd.read_csv('employee.csv')


filter1 = df['DEPARTMENT'].isin(['Houston Police Department-HPD', 'Houston Fire Department (HFD)'])
filter2 = df['GENDER'] == 'Female'
filter3 = df['BASE_SALARY'].between(80000,120000)
columns = ['UNIQUE_ID', 'DEPARTMENT', 'BASE_SALARY', 'GENDER']
fin_filt = filter1 & filter2 & filter3
df.loc[fin_filt, columns]
# Out:
#       UNIQUE_ID                     DEPARTMENT  BASE_SALARY  GENDER
# 61           61  Houston Fire Department (HFD)      96668.0  Female
# 136         136  Houston Police Department-HPD      81239.0  Female
# 367         367  Houston Police Department-HPD      86534.0  Female
# 474         474  Houston Police Department-HPD      91181.0  Female
# 513         513  Houston Police Department-HPD      81239.0  Female
# 564         564  Houston Police Department-HPD      81239.0  Female
# 595         595  Houston Police Department-HPD      99953.0  Female
# 937         937  Houston Police Department-HPD      81239.0  Female
# 954         954  Houston Police Department-HPD      91181.0  Female
# 1118       1118  Houston Police Department-HPD     104455.0  Female
# 1519       1519  Houston Police Department-HPD      91181.0  Female
# 1565       1565  Houston Police Department-HPD      81239.0  Female
# 1622       1622  Houston Police Department-HPD      91181.0  Female

# %%
df = pd.read_csv('employee.csv')
filt1 = df['EMPLOYMENT_STATUS'] == 'Active' 
filt2 = df['GENDER'] == 'Male'
filt3 = df['BASE_SALARY'] > 100000
filt4 = df['POSITION_TITLE'] == 'POLICE OFFICER'
filt_final = filt1 & filt2 & filt3 & filt4
df[filt_final]
# Out:
# Empty DataFrame
# Columns: [UNIQUE_ID, POSITION_TITLE, DEPARTMENT, BASE_SALARY, RACE, EMPLOYMENT_TYPE, GENDER, EMPLOYMENT_STATUS, HIRE_DATE, JOB_DATE]
# Index: []
